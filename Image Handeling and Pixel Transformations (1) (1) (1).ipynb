# %% [markdown]
# # Ex. No: 01
# # Image Handling and Pixel Transformations Using OpenCV
#
# **Name:** LOGESH N A  **Reg. No:** 212223240078

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# 1. Read the image ('Eagle_in_Flight.jpg') using OpenCV imread() as a grayscale image.

# %%
bgr_img=cv2.imread('Eagle_in_Flight.jpg')

# %% [markdown]
# 2. Print the image width, height & Channel

# %%
bgr_img.shape
# Out:
# (600, 768, 3)

# %% [markdown]
# 3. Display the image using matplotlib imshow().

# %%
plt.imshow(bgr_img)
plt.title('BGR Image')
plt.axis('on')
plt.show()

# %% [markdown]
# 4. Save the image as a PNG file using OpenCV imwrite().

# %%
cv2.imwrite('output_image.jpg', bgr_img)
# Out:
# True

# %% [markdown]
# 5. Read the saved image above as a color image using cv2.cvtColor().

# %%
jpg_img = cv2.imread('output_image.jpg')

saved_color_img = cv2.cvtColor(jpg_img, cv2.COLOR_BGR2RGB)

# %% [markdown]
# 6. Display the Colour image using matplotlib imshow() & Print the image width, height & channel

# %%
plt.imshow (saved_color_img)
plt.title('Color Image')
plt.axis('on')
plt.show()

# %% [markdown]
# 7. Crop the image to extract any specific (Eagle alone)  object from the image.

# %%
cropped_img = saved_color_img[50:425,200:550]

plt.imshow(cropped_img[:,:,::-1])
plt.title('Cropped image')
plt.axis('off')
plt.show()

# %% [markdown]
# 8. Resize the image up by a factor of 2x.

# %%
resized_img = cv2.resize(cropped_img, None, fx=50, fy=50, interpolation=cv2.INTER_LINEAR)

# %% [markdown]
# 9. Flip the cropped/resized image horizontally. (Eagle Image)

# %%
flipped_img = cv2.flip(cropped_img, 1)

plt.imshow(flipped_img[:,:,::-1])
plt.title('Flipped Image')
plt.axis('off')
plt.show()

# %%
flipped_img = cv2.flip(cropped_img, 0)

plt.imshow(flipped_img[:,:,::-1])
plt.title('Vertical Flip')
plt.axis('off')
plt.show()

# %%
flipped_img = cv2.flip(cropped_img, -1)

plt.imshow(flipped_img[:,:,::-1])
plt.title('Both Flipped')
plt.axis('off')
plt.show()

# %% [markdown]
# 10. Read in the image ('Apollo-11-launch.jpg').

# %%
apollo_img = cv2.imread('Apollo-11-launch.jpg')
apollo_img = cv2.cvtColor(apollo_img, cv2.COLOR_BGR2RGB)

# %% [markdown]
# 11. Add the following text to the dark area at the bottom of the image (centered on the image):

# %%
text = 'Apollo 11 Saturn V Launch, July 16, 1969'
font_face = cv2.FONT_HERSHEY_PLAIN

height, width, _ = apollo_img.shape

(text_w, text_h), baseline = cv2.getTextSize(text, font_face, 2, 2)

x = (width - text_w) // 2
y = height - 50 
cv2.putText(apollo_img, text, (x, y), font_face, 2, (255, 255, 255), 2, cv2.LINE_AA)

plt.imshow(apollo_img)
plt.axis('on')
plt.show()

# %% [markdown]
# 12. Draw a magenta rectangle that encompasses the launch tower and the rocket.

# %%
x1, y1 = 500, 50     
x2, y2 = 700, 600    

cv2.rectangle(apollo_img, (x1, y1), (x2, y2), (255, 0, 255), 3)

plt.imshow(apollo_img)
plt.axis('off')
plt.show()

# %% [markdown]
# 13. Display the final annotated image.

# %%
plt.imshow(apollo_img)
plt.axis("off")
plt.show()

# %% [markdown]
# 14. Read the image ('boy.jpg').

# %%
img_boy = cv2.imread("boy.jpg")

# %% [markdown]
# 15. Adjust the brightness of the image.

# %%
bright_boy = cv2.convertScaleAbs(img_boy, alpha=1, beta=50)

# %% [markdown]
# 16. Create brighter and darker images.

# %%
import numpy as np
matrix = np.ones(img_boy.shape, dtype="uint8") * 50  

img_brighter = cv2.add(img_boy, matrix)

img_darker = cv2.subtract(img_boy, matrix)

# %% [markdown]
# 17. Display the images (Original Image, Darker Image, Brighter Image).

# %%
plt.figure(figsize=(12,4))

plt.subplot(1,3,1)
plt.imshow(cv2.cvtColor(img_boy, cv2.COLOR_BGR2RGB))
plt.title("Original")
plt.axis("off")

plt.subplot(1,3,2)
plt.imshow(cv2.cvtColor(img_darker, cv2.COLOR_BGR2RGB))
plt.title("Darker")
plt.axis("off")

plt.subplot(1,3,3)
plt.imshow(cv2.cvtColor(img_brighter, cv2.COLOR_BGR2RGB))
plt.title("Brighter")
plt.axis("off")

plt.show()

# %% [markdown]
# 18. Modify the image contrast.

# %%
matrix1 = np.ones(img_boy.shape, dtype="uint8") * 1
matrix2 = np.ones(img_boy.shape, dtype="uint8") * 1

img_higher1 = cv2.convertScaleAbs(img_boy, alpha=1.1, beta=0)  # Contrast factor 1.1
img_higher2 = cv2.convertScaleAbs(img_boy, alpha=1.2, beta=0)  # Contrast factor 1.2

# %% [markdown]
# 19. Display the images (Original, Lower Contrast, Higher Contrast).

# %%
plt.figure(figsize=(12,4))

plt.subplot(1,3,1)
plt.imshow(cv2.cvtColor(img_boy, cv2.COLOR_BGR2RGB))
plt.title("Original")
plt.axis("off")

img_lower = cv2.convertScaleAbs(img_boy, alpha=0.9, beta=0)
plt.subplot(1,3,2)
plt.imshow(cv2.cvtColor(img_lower, cv2.COLOR_BGR2RGB))
plt.title("Lower Contrast")
plt.axis("off")

plt.subplot(1,3,3)
plt.imshow(cv2.cvtColor(img_higher2, cv2.COLOR_BGR2RGB))
plt.title("Higher Contrast")
plt.axis("off")

plt.show()

# %% [markdown]
# 20. Split the image (boy.jpg) into the B,G,R components & Display the channels.

# %%
B, G, R = cv2.split(img_boy)

plt.figure(figsize=(12,4))

plt.subplot(1,3,1)
plt.imshow(B, cmap="gray")
plt.title("Blue Channel")
plt.axis("off")

plt.subplot(1,3,2)
plt.imshow(G, cmap="gray")
plt.title("Green Channel")
plt.axis("off")

plt.subplot(1,3,3)
plt.imshow(R, cmap="gray")
plt.title("Red Channel")
plt.axis("off")

plt.show()

# %% [markdown]
# 21. _merged the R, G, B , display along with orginal image

# %%
img_merged = cv2.merge([B, G, R])

plt.figure(figsize=(10,5))

plt.subplot(1,2,1)
plt.imshow(cv2.cvtColor(img_boy, cv2.COLOR_BGR2RGB))
plt.title("Original Image")
plt.axis("off")

plt.subplot(1,2,2)
plt.imshow(cv2.cvtColor(img_merged, cv2.COLOR_BGR2RGB))
plt.title("Merged Image (B+G+R)")
plt.axis("off")

plt.show()

# %% [markdown]
# 22. Split the image into the H, S, V components &  Display the channels.

# %%
hsv_img = cv2.cvtColor(img_boy, cv2.COLOR_BGR2HSV)

H, S, V = cv2.split(hsv_img)

plt.figure(figsize=(12,4))

plt.subplot(1,3,1)
plt.imshow(H, cmap="gray")
plt.title("Hue Channel")
plt.axis("off")

plt.subplot(1,3,2)
plt.imshow(S, cmap="gray")
plt.title("Saturation Channel")
plt.axis("off")

plt.subplot(1,3,3)
plt.imshow(V, cmap="gray")
plt.title("Value Channel")
plt.axis("off")

plt.show()

# %% [markdown]
# 23. _merged the H, S, V, display along with orginal image

# %%
hsv_merged = cv2.merge([H, S, V])

img_hsv2bgr = cv2.cvtColor(hsv_merged, cv2.COLOR_HSV2BGR)

plt.figure(figsize=(10,5))

plt.subplot(1,2,1)
plt.imshow(cv2.cvtColor(img_boy, cv2.COLOR_BGR2RGB))
plt.title("Original Image")
plt.axis("off")

plt.subplot(1,2,2)
plt.imshow(cv2.cvtColor(img_hsv2bgr, cv2.COLOR_BGR2RGB))
plt.title("Merged Image (H+S+V)")
plt.axis("off")

plt.show()
